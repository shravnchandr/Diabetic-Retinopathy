# %% [markdown]
# # Final Research Project: Ammar Chalifah
# **Based on Shidqie's Research**

# %%
import tensorflow as tf
from keras import layers
from tensorflow.keras import applications 
from keras.callbacks import Callback, ModelCheckpoint
from keras.models import Sequential
from keras.optimizers import Adam
from keras import models

from sklearn.metrics import cohen_kappa_score, accuracy_score, confusion_matrix
from tqdm import tqdm

# %%
import numpy
import pandas

aptos_df = pandas.read_csv("../input/aptos2019-blindness-detection/train.csv")
aptos_dir = "../input/aptos2019-blindness-detection/train_images/"
images = []
labels = []

for idx in tqdm(range(len(aptos_df))):
#     images.append(load_ben_color(aptos_dir+aptos_df.iloc[idx]['id_code']+'.png', 20))
    labels.append(aptos_df.iloc[idx]['diagnosis'])
#     images.append(load_ben_color(dr_dir+dr_df.iloc[idx]['image']+'.jpeg'))
#     labels.append(dr_df.iloc[idx]['level'])

from tensorflow.keras.utils import to_categorical
images = numpy.load('../input/aptosnumpy/images.npy')
# images = numpy.array(images)
labels = numpy.array(labels)
# cat_labels = to_categorical(labels)

# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(images, cat_labels, 
#                                                     test_size=0.3, shuffle=True,
#                                                     random_state=42, stratify=labels)
# Out:
# 100%|██████████| 3662/3662 [00:00<00:00, 7059.68it/s]

# %%
class Metrics(Callback):
    def __init__(self, xval, yval):
        super().__init__()
        self.xval = xval
        self.yval = yval
        
    def on_train_begin(self, logs={}):
        self.val_kappas = []

    def on_epoch_end(self, epoch, logs={}):
        X_val = self.xval
        y_val = self.yval
        
        y_pred = self.model.predict(X_val)
        y_pred = numpy.clip(y_pred,0,4)
        y_pred = y_pred.astype(int)

        _val_kappa = cohen_kappa_score(
            y_val,
            y_pred, 
            weights='quadratic'
        )

        self.val_kappas.append(_val_kappa)

        print(f"val_kappa: {_val_kappa:.4f}")
        
        if _val_kappa == max(self.val_kappas):
            print("Validation Kappa has improved. Saving model.")
            self.model.save('model.h5')

        return
    
kappa_metrics = Metrics(images, labels)

# %%
xception = applications.Xception(include_top=False, weights='imagenet')

def build_model():
    model = Sequential()
    model.add(xception)
    model.add(layers.GlobalMaxPooling2D())
    model.add(layers.Dense(256))
    model.add(layers.Dense(256))
    model.add(layers.Dense(1))
    
    model.compile(loss='mse', optimizer=Adam(lr=0.0001), metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=4, shuffle=True, random_state=42)

for train_index, test_index in skf.split(images, labels):
    x_train, x_test = images[train_index], images[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    history = model.fit(x_train, y_train, epochs=8, batch_size=32,
    validation_data = (x_test, y_test), callbacks=[kappa_metrics])
# Out:
# Epoch 1/8
# 86/86 [==============================] - 55s 553ms/step - loss: 1.3832 - accuracy: 0.4670 - val_loss: 0.6957 - val_accuracy: 0.2413
# val_kappa: 0.6952
# Validation Kappa has improved. Saving model.
# Epoch 2/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.2897 - accuracy: 0.5433 - val_loss: 0.5393 - val_accuracy: 0.4563
# val_kappa: 0.7370
# Validation Kappa has improved. Saving model.
# Epoch 3/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.2089 - accuracy: 0.5552 - val_loss: 0.4177 - val_accuracy: 0.5262
# val_kappa: 0.9150
# Validation Kappa has improved. Saving model.
# Epoch 4/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.1515 - accuracy: 0.5708 - val_loss: 0.4271 - val_accuracy: 0.5557
# val_kappa: 0.8039
# Epoch 5/8
# 86/86 [==============================] - 45s 523ms/step - loss: 0.0768 - accuracy: 0.5853 - val_loss: 0.3757 - val_accuracy: 0.5579
# val_kappa: 0.8896
# Epoch 6/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0605 - accuracy: 0.5811 - val_loss: 0.3838 - val_accuracy: 0.5655
# val_kappa: 0.8502
# Epoch 7/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0696 - accuracy: 0.5729 - val_loss: 0.3689 - val_accuracy: 0.5622
# val_kappa: 0.8708
# Epoch 8/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0614 - accuracy: 0.5998 - val_loss: 0.3806 - val_accuracy: 0.5677
# val_kappa: 0.8289
# Epoch 1/8
# 86/86 [==============================] - 45s 526ms/step - loss: 0.1792 - accuracy: 0.5787 - val_loss: 0.0638 - val_accuracy: 0.5906
# val_kappa: 0.9404
# Validation Kappa has improved. Saving model.
# Epoch 2/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0945 - accuracy: 0.5885 - val_loss: 0.0596 - val_accuracy: 0.5906
# val_kappa: 0.8981
# Epoch 3/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0819 - accuracy: 0.5870 - val_loss: 0.1182 - val_accuracy: 0.5895
# val_kappa: 0.8205
# Epoch 4/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0576 - accuracy: 0.5896 - val_loss: 0.0683 - val_accuracy: 0.5884
# val_kappa: 0.9163
# Epoch 5/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0456 - accuracy: 0.5892 - val_loss: 0.0681 - val_accuracy: 0.5906
# val_kappa: 0.8970
# Epoch 6/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0396 - accuracy: 0.5899 - val_loss: 0.0722 - val_accuracy: 0.5862
# val_kappa: 0.9032
# Epoch 7/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0352 - accuracy: 0.5921 - val_loss: 0.0914 - val_accuracy: 0.5895
# val_kappa: 0.8431
# Epoch 8/8
# 86/86 [==============================] - 45s 523ms/step - loss: 0.0471 - accuracy: 0.5921 - val_loss: 0.0698 - val_accuracy: 0.5884
# val_kappa: 0.9015
# Epoch 1/8
# 86/86 [==============================] - 47s 544ms/step - loss: 0.0592 - accuracy: 0.5897 - val_loss: 0.0370 - val_accuracy: 0.5891
# val_kappa: 0.8919
# Validation Kappa has improved. Saving model.
# Epoch 2/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0450 - accuracy: 0.5919 - val_loss: 0.0361 - val_accuracy: 0.5913
# val_kappa: 0.8946
# Validation Kappa has improved. Saving model.
# Epoch 3/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0394 - accuracy: 0.5916 - val_loss: 0.0444 - val_accuracy: 0.5913
# val_kappa: 0.8817
# Epoch 4/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0361 - accuracy: 0.5923 - val_loss: 0.0455 - val_accuracy: 0.5913
# val_kappa: 0.9443
# Validation Kappa has improved. Saving model.
# Epoch 5/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0397 - accuracy: 0.5916 - val_loss: 0.0438 - val_accuracy: 0.5913
# val_kappa: 0.9044
# Epoch 6/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0336 - accuracy: 0.5923 - val_loss: 0.0519 - val_accuracy: 0.5913
# val_kappa: 0.8745
# Epoch 7/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0338 - accuracy: 0.5930 - val_loss: 0.0508 - val_accuracy: 0.5913
# val_kappa: 0.8798
# Epoch 8/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0308 - accuracy: 0.5916 - val_loss: 0.0500 - val_accuracy: 0.5913
# val_kappa: 0.9254
# Epoch 1/8
# 86/86 [==============================] - 45s 526ms/step - loss: 0.0478 - accuracy: 0.5919 - val_loss: 0.0300 - val_accuracy: 0.5934
# val_kappa: 0.9584
# Validation Kappa has improved. Saving model.
# Epoch 2/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0366 - accuracy: 0.5926 - val_loss: 0.0304 - val_accuracy: 0.5902
# val_kappa: 0.9119
# Epoch 3/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0330 - accuracy: 0.5930 - val_loss: 0.0328 - val_accuracy: 0.5902
# val_kappa: 0.9049
# Epoch 4/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0323 - accuracy: 0.5937 - val_loss: 0.0430 - val_accuracy: 0.5902
# val_kappa: 0.8550
# Epoch 5/8
# 86/86 [==============================] - 45s 525ms/step - loss: 0.0264 - accuracy: 0.5930 - val_loss: 0.0533 - val_accuracy: 0.5902
# val_kappa: 0.8399
# Epoch 6/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0253 - accuracy: 0.5926 - val_loss: 0.0433 - val_accuracy: 0.5891
# val_kappa: 0.9385
# Epoch 7/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0285 - accuracy: 0.5934 - val_loss: 0.0440 - val_accuracy: 0.5902
# val_kappa: 0.9047
# Epoch 8/8
# 86/86 [==============================] - 45s 524ms/step - loss: 0.0282 - accuracy: 0.5934 - val_loss: 0.0452 - val_accuracy: 0.5902
# val_kappa: 0.9243
